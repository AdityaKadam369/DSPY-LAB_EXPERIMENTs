# %% [markdown]
# <a href="https://colab.research.google.com/github/AdityaKadam369/DSPY-LAB_EXPERIMENTs/blob/main/Notebook_2_%E2%80%94_Exploratory_Data_Analysis_(EDA)_2301618.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Notebook02: Exploratory Data Analysis (EDA)**

# %% [markdown]
# ####**Aim:** To perform exploratory data analysis on the dataset using graphical and non-graphical techniques.

# %% [markdown]
# **Introduction to Exploratory Data Analysis:**
#
# Exploratory Data Analysis (EDA) is the process of analyzing datasets to summarize their main characteristics. It helps in understanding patterns, detecting anomalies, checking assumptions, and preparing data for modeling.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1930769a-07f3-4f19-8cbf-ddc8b4601c88" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1930769a-07f3-4f19-8cbf-ddc8b4601c88">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("Teen_Mental_Health_Cleaned.csv")
df.head()
# Out:
#    age  gender  daily_social_media_hours platform_usage  sleep_hours  \
# 0   14    male                       7.9      Instagram          7.4
# 1   19  female                       1.9         TikTok          8.0
# 2   17  female                       1.3      Instagram          7.6
# 3   15    male                       7.4         TikTok          6.9
# 4   15  female                       4.7           Both          4.9
#
#    screen_time_before_sleep  academic_performance  physical_activity  \
# 0                       2.9                  3.01                1.5
# 1                       2.9                  3.22                0.8
# 2                       0.5                  3.92                0.0
# 3                       1.6                  3.48                0.8
# 4                       3.0                  2.37                1.4
#
#   social_interaction_level  stress_level  anxiety_level  addiction_level  \
# ...

# %% [markdown]
# **Data Inspection:**
#
# After loading the dataset, the first few rows are displayed using `head()` function.
#
# This helps to:
#
# *   Understand column names
# *   View sample data
# *   Verify successful loading

# %%
df.shape()
# Out:
# (1200, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       1200 non-null   int64
#  1   gender                    1200 non-null   object
#  2   daily_social_media_hours  1200 non-null   float64
#  3   platform_usage            1200 non-null   object
#  4   sleep_hours               1200 non-null   float64
#  5   screen_time_before_sleep  1200 non-null   float64
#  6   academic_performance      1200 non-null   float64
#  7   physical_activity         1200 non-null   float64
#  8   social_interaction_level  1200 non-null   object
#  9   stress_level              1200 non-null   int64
#  10  anxiety_level             1200 non-null   int64
#  11  addiction_level           1200 non-null   int64
#  12  depression_label          1200 non-null   int64
# dtypes: float64(5), int64(5), object(3)
# ...

# %% [markdown]
# **Dataset Overview:**
#
# The structure of the dataset is examined using functions like `shape()` and `info()`. This helps identify:
#
# *   Number of rows and columns
# *   Non-null values
# *   Data types of attributes

# %%
df.describe()
# Out:
#                age  daily_social_media_hours  sleep_hours  \
# count  1200.000000               1200.000000  1200.000000
# mean     15.928333                  4.536667     6.449417
# std       2.021947                  2.029599     1.442677
# min      13.000000                  1.000000     4.000000
# 25%      14.000000                  2.800000     5.200000
# 50%      16.000000                  4.500000     6.500000
# 75%      18.000000                  6.300000     7.600000
# max      19.000000                  8.000000     9.000000
#
#        screen_time_before_sleep  academic_performance  physical_activity  \
# count               1200.000000           1200.000000        1200.000000
# mean                   1.740333              2.990383           1.014500
# std                    0.716660              0.576758           0.582185
# min                    0.500000              2.000000           0.000000
# 25%                    1.100000              2.500000           0.500000
# ...

# %% [markdown]
# **Statistical Summary (Non-Graphical Analysis):**
#
# The `describe()` function provides summary statistics such as:
#
# *  Mean
# *  Standard deviation
# *  Minimum and maximum values
# *  Quartiles
#
# These measures help understand distribution and variability of numerical features.
#
# **Correlation Analysis (Non-Graphical Analysis):**
#
# Correlation analysis is performed to identify relationships between numerical variables. A correlation matrix is generated which shows how strongly variables are related to each other.

# %%
df.corr(numeric_only=True)
# Out:
#                                age  daily_social_media_hours  sleep_hours  \
# age                       1.000000                 -0.006635     0.001530
# daily_social_media_hours -0.006635                  1.000000    -0.009472
# sleep_hours               0.001530                 -0.009472     1.000000
# screen_time_before_sleep  0.075612                  0.035777     0.010235
# academic_performance     -0.013973                  0.013179     0.021866
# physical_activity         0.011086                  0.025546     0.012701
# stress_level             -0.031208                  0.030698    -0.010979
# anxiety_level             0.026363                  0.027835    -0.011879
# addiction_level           0.038265                 -0.024964    -0.054838
# depression_label          0.010973                  0.175201    -0.190630
#
#                           screen_time_before_sleep  academic_performance  \
# age                                       0.075612             -0.013973
# ...

# %% [markdown]
# ###**Univariate Analysis (Graphical):**
#
# Univariate analysis involves analyzing one variable at a time.
# Histograms and count plots are used to visualize:
#
# * Frequency distribution
# * Spread of data
# * Central tendency
#
# ###**Multivariate Analysis (Graphical):**
#
# Multivariate analysis examines relationships between two or more variables.
# Scatter plots and pairwise comparisons are used to identify trends and dependencies among features.

# %% [markdown]
# ###**Histogram (Univariate Analysis):**
#
# Histogram is a graphical representation used to display the distribution of a single numerical variable. It divides the data into intervals called bins and shows the frequency of data points in each bin.
#
# In this dataset, histograms are used to understand:
#
# *   Distribution of student-related numerical attributes
# *   Spread of values
# *   Central tendency of data
# *   Presence of skewness or unusual patterns
#
# Univariate analysis focuses on analyzing one variable at a time. Histograms help visualize how values of each attribute are distributed across the dataset.

# %%
df.hist(figsize=(10,8))
plt.show()

# %% [markdown]
# df.hist(figsize=(10,8))
#
# * `df.hist()` generates histograms for all numerical columns in the dataset.
# * Each column gets its own histogram.
# * figsize=(10,8) sets the size of the figure:
#
#   * Width = 10
#
#   * Height = 8
#
#     This makes plots bigger and easier to read.
# `plt.show()`
#   * plt.show() displays the generated histograms.
#   * Without this, plots may not appear properly.

# %% [markdown]
# ###**Count Plot (Categorical):**
#
# Count plot is used to visualize the frequency of categorical variables in the dataset.
# It displays the number of occurrences of each category using bars.
# This helps in understanding the distribution of categorical data such as gender, grade, performance level, etc.
#
# Count plots are useful for:
#
# 1. Identifying most frequent category.
# 2. Comparing category counts.
# 3. Understanding class imbalance.

# %%
sns.countplot(x=df.iloc[:,0])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# sns.countplot(x=df.iloc[:,0])
# * sns refers to seaborn visualization library
# * `countplot()` creates a bar chart showing counts
# * `df.iloc[:,0]` selects first column of dataset
# * The function counts occurrences of each category
#
# plt.xticks(rotation=45)
#
# * Rotates x-axis labels by 45 degrees
# * Prevents overlapping of category names
# * Improves readability

# %% [markdown]
# ###**Boxplot Analysis:**
#
# A boxplot is a graphical representation used to visualize the distribution of numerical data. It displays the following statistical measures:
#
# * Minimum value
# * First Quartile (Q1)
# * Median (Q2)
# * Third Quartile (Q3)
# * Maximum value
# * Outliers (if present)
#
# Boxplots help in identifying:
#
# * Spread of the data
# * Skewness of distribution
# * Presence of extreme values (outliers)
#
# In this analysis, boxplot is used to detect outliers in the student dataset and understand the distribution of numerical attributes.

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The code first creates a figure of size 8×5 inches using `plt.figure(figsize=(8,5))` so that the boxplot is clearly visible.
#
# Then `sns.boxplot(data=df)` generates boxplots for all numerical columns in the dataframe, helping visualize the distribution and detect outliers.
#
# The `plt.xticks(rotation=90)` function rotates the x-axis labels by 90 degrees to prevent overlapping and improve readability of column names. Finally, `plt.show()` is used to display the boxplot on the screen.

# %% [markdown]
# ###**Scatter Plot (Multivariate Analysis):**
#
# Multivariate analysis is used to study the relationship between two or more variables.
# A scatter plot is used to visualize how one numerical variable changes with respect to another numerical variable.
#
# Each point in the scatter plot represents one observation from the dataset.
# This visualization helps to:
#
# * Identify trends
# * Detect relationships between variables
# * Observe clusters
# * Identify outliers
#
# In this notebook, a scatter plot is created using two numerical columns from the student dataset to analyze their relationship.

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x=df.select_dtypes(include=np.number).columns[0],
                y=df.select_dtypes(include=np.number).columns[1],
                data=df)
plt.show()

# %% [markdown]
# This code creates a scatter plot to show the relationship between two numerical columns in the dataset. The figure size is set using `plt.figure().` `The sns.scatterplot()` function selects the first two numerical columns for the x and y axes from the dataframe. Finally, `plt.show()` displays the plot.

# %% [markdown]
# ###**Heatmap (Correlation Visualization):**
#
# A heatmap is a graphical representation used to visualize the correlation matrix of numerical variables.
# It uses different colors to represent the strength of relationships between variables.
#
# * Darker colors indicate stronger correlation
# * Lighter colors indicate weaker correlation
# * Positive values show direct relationship
# * Negative values show inverse relationship
#
# Heatmaps help in identifying which student attributes are strongly related to each other. This is useful for feature selection before applying machine learning models.

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()

# %% [markdown]
# This code generates a heatmap to visualize the correlation between numerical variables in the dataset. The `plt.figure(figsize=(8,6))` function sets the size of the plot. The `df.corr(numeric_only=True)` computes the correlation matrix for numeric columns. The `sns.heatmap()` function displays the matrix using colors, and annot=True shows the correlation values inside each cell. Finally, `plt.show()` is used to display the heatmap.

# %% [markdown]
# ##**Conclusion:**
#
# EDA helps understand dataset characteristics and relationships between variables. The insights obtained from EDA assist in selecting suitable machine learning models for further analysis.
